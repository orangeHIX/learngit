# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('Assignment 5.xlsx', 'Ratings', index_col=0)

# %%
data
# Out:
#       1: Toy Story (1995)  \
# User
# 755               2.00000
# 5277              1.00000
# 1577                  NaN
# 4388              2.00000
# 1202                  NaN
# 3823              3.00000
# 5448                  NaN
# 5347              2.00000
# 4117              4.00000
# 2765              4.00000
# 5450              5.00000
# 139               2.00000
# 1940              4.00000
# 3118              3.00000
# 4656              2.00000
# 4796                  NaN
# 6037              2.00000
# 3048              4.00000
# 4790              2.00000
# 4489              2.00000
# L2               11.83216
#
#       1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# User
# 755                                            5.000000
# 5277                                                NaN
# 1577                                                NaN
# 4388                                           3.000000
# 1202                                           3.000000
# ...

# %%
r_data = data[0:-1]

# %%
from scipy.spatial.distance import squareform, pdist

# %%
sim = pd.DataFrame(squareform(pdist(r_data.fillna(0).T.ix[:, :])), columns=r_data.columns, index = r_data.columns)
